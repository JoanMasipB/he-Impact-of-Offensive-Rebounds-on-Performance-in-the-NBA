# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import re

df = pd.read_parquet("archive\csv\play_by_play.parquet")

df.head()
# Out:
#     game_id  eventnum  eventmsgtype  eventmsgactiontype  period wctimestring  \
# 0  29600012         0            12                   0       1     14:43 PM
# 1  29600012         2            10                   0       1     14:50 PM
# 2  29600012         3             2                   1       1     14:51 PM
# 3  29600012         4             4                   0       1     14:51 PM
# 4  29600012         5             2                   1       1     14:51 PM
#
#   pctimestring                              homedescription  \
# 0        12:00                                         None
# 1        12:00  Jump Ball O'Neal vs. Kleine: Tip to Cassell
# 2        11:45                                         None
# 3        11:43                 O'Neal REBOUND (Off:0 Def:1)
# 4        11:29              MISS Ceballos 26' 3PT Jump Shot
#
#                    neutraldescription          visitordescription  ...  \
# 0  Start of 1st Period (14:43 PM EST)                        None  ...
# 1                                None                        None  ...
# 2                                None  MISS Cassell 15' Jump Shot  ...
# 3                                None                        None  ...
# 4                                None                        None  ...
#
#   player2_team_nickname player2_team_abbreviation  person3type  player3_id  \
# 0                  None                      None          0.0           0
# 1                  Suns                       PHX          5.0         208
# 2                  None                      None          0.0           0
# 3                  None                      None          0.0           0
# 4                  None                      None          0.0           0
#
#   player3_name  player3_team_id player3_team_city player3_team_nickname  \
# 0         None              NaN              None                  None
# 1  Sam Cassell     1.610613e+09           Phoenix                  Suns
# 2         None              NaN              None                  None
# 3         None              NaN              None                  None
# 4         None              NaN              None                  None
#
#   player3_team_abbreviation  video_available_flag
# 0                      None                     0
# 1                       PHX                     0
# 2                      None                     0
# 3                      None                     0
# 4                      None                     0
#
# [5 rows x 34 columns]

# %%
pd.set_option('display.max_columns', None)

# %%
# Code to separate the offensive rebounds from the defensive ones and give them a new number in the column "eventmsgtype" (n 14)
df["player"] = df["homedescription"].str.extract(r"^(.*?) REBOUND")
df["offensive_rebounds"] = (
    df["homedescription"]
    .str.extract(r'Off:(\d+)')[0]
    .fillna(0)
    .astype(int)
)

df["is_offensive_rebound"] = (
    df.groupby("player")["offensive_rebounds"]
    .diff()
    .fillna(0) > 0
)

first_rebounds = df.groupby("player").head(1)
df.loc[first_rebounds.index, "is_offensive_rebound"] = (
    first_rebounds["offensive_rebounds"] > 0
)

df.loc[df["is_offensive_rebound"], "eventmsgtype"] = 14

df = df.drop(columns=["player", "offensive_rebounds", "is_offensive_rebound"])

# Same for visitordescription:
df["player"] = df["visitordescription"].str.extract(r"^(.*?) REBOUND")
df["offensive_rebounds"] = (
    df["visitordescription"]
    .str.extract(r'Off:(\d+)')[0]
    .fillna(0)
    .astype(int)
)

df["is_offensive_rebound"] = (
    df.groupby("player")["offensive_rebounds"]
    .diff()
    .fillna(0) > 0
)

first_rebounds = df.groupby("player").head(1)
df.loc[first_rebounds.index, "is_offensive_rebound"] = (
    first_rebounds["offensive_rebounds"] > 0
)

df.loc[df["is_offensive_rebound"], "eventmsgtype"] = 14

df = df.drop(columns=["player", "offensive_rebounds", "is_offensive_rebound"])

print(df)
# Out:
#            game_id  eventnum  eventmsgtype  eventmsgactiontype  period  \
# 0         29600012         0            12                   0       1
# 1         29600012         2            10                   0       1
# 2         29600012         3             2                   1       1
# 3         29600012         4             4                   0       1
# 4         29600012         5             2                   1       1
# ...            ...       ...           ...                 ...     ...
# 13592894  32200001       638             1                  79       4
# 13592895  32200001       639             2                   1       4
# 13592896  32200001       640            14                   0       4
# 13592897  32200001       641             1                  79       4
# 13592898  32200001       642            13                   0       4
#
#          wctimestring pctimestring  \
# 0            14:43 PM        12:00
# 1            14:50 PM        12:00
# 2            14:51 PM        11:45
# 3            14:51 PM        11:43
# 4            14:51 PM        11:29
# ...               ...          ...
# 13592894     10:54 PM         0:00
# 13592895     10:54 PM         0:00
# 13592896     10:54 PM         0:00
# 13592897     10:54 PM         0:00
# 13592898     10:55 PM         0:00
#
#                                       homedescription  \
# 0                                                None
# 1         Jump Ball O'Neal vs. Kleine: Tip to Cassell
# 2                                                None
# 3                        O'Neal REBOUND (Off:0 Def:1)
# 4                     MISS Ceballos 26' 3PT Jump Shot
# ...                                               ...
# 13592894      Brown 30' 3PT Pullup Jump Shot (35 PTS)
# 13592895                                         None
# 13592896                                         None
# 13592897                                         None
# 13592898                                         None
#
#                           neutraldescription  \
# 0         Start of 1st Period (14:43 PM EST)
# 1                                       None
# 2                                       None
# 3                                       None
# 4                                       None
# ...                                      ...
# 13592894                                None
# 13592895                                None
# 13592896                                None
# 13592897                                None
# 13592898    End of 4th Period (10:55 PM EST)
#
#                                  visitordescription      score scoremargin  \
# 0                                              None       None        None
# 1                                              None       None        None
# 2                        MISS Cassell 15' Jump Shot       None        None
# 3                                              None       None        None
# 4                                              None       None        None
# ...                                             ...        ...         ...
# 13592894                                       None  181 - 175          -6
# 13592895           MISS Markkanen 24' 3PT Jump Shot       None        None
# 13592896              Lillard REBOUND (Off:1 Def:2)       None        None
# 13592897  Lillard 30' 3PT Pullup Jump Shot (26 PTS)  184 - 175          -9
# 13592898                                       None  184 - 175          -9
#
#           person1type  player1_id      player1_name  player1_team_id  \
# 0                 0.0           0              None              NaN
# 1                 4.0         406  Shaquille O'Neal     1.610613e+09
# 2                 5.0         208       Sam Cassell     1.610613e+09
# 3                 4.0         406  Shaquille O'Neal     1.610613e+09
# 4                 4.0          76   Cedric Ceballos     1.610613e+09
# ...               ...         ...               ...              ...
# 13592894          4.0     1627759      Jaylen Brown     1.610617e+09
# 13592895          5.0     1628374   Lauri Markkanen     1.610617e+09
# 13592896          5.0      203081    Damian Lillard     1.610617e+09
# 13592897          5.0      203081    Damian Lillard     1.610617e+09
# 13592898          0.0           0              None              NaN
#
#          player1_team_city player1_team_nickname player1_team_abbreviation  \
# 0                     None                  None                      None
# 1              Los Angeles                Lakers                       LAL
# 2                  Phoenix                  Suns                       PHX
# 3              Los Angeles                Lakers                       LAL
# 4              Los Angeles                Lakers                       LAL
# ...                    ...                   ...                       ...
# 13592894              Team                LeBron                       LBN
# 13592895              Team               Giannis                       GNS
# 13592896              Team               Giannis                       GNS
# 13592897              Team               Giannis                       GNS
# 13592898              None                  None                      None
#
#           person2type  player2_id player2_name  player2_team_id  \
# 0                 0.0           0         None              NaN
# 1                 5.0         170   Joe Kleine     1.610613e+09
# 2                 0.0           0         None              NaN
# 3                 0.0           0         None              NaN
# 4                 0.0           0         None              NaN
# ...               ...         ...          ...              ...
# 13592894          0.0           0         None              NaN
# 13592895          0.0           0         None              NaN
# 13592896          0.0           0         None              NaN
# 13592897          0.0           0         None              NaN
# 13592898          0.0           0         None              NaN
#
#          player2_team_city player2_team_nickname player2_team_abbreviation  \
# 0                     None                  None                      None
# 1                  Phoenix                  Suns                       PHX
# 2                     None                  None                      None
# 3                     None                  None                      None
# 4                     None                  None                      None
# ...                    ...                   ...                       ...
# 13592894              None                  None                      None
# 13592895              None                  None                      None
# 13592896              None                  None                      None
# 13592897              None                  None                      None
# 13592898              None                  None                      None
#
#           person3type  player3_id player3_name  player3_team_id  \
# 0                 0.0           0         None              NaN
# 1                 5.0         208  Sam Cassell     1.610613e+09
# 2                 0.0           0         None              NaN
# 3                 0.0           0         None              NaN
# 4                 0.0           0         None              NaN
# ...               ...         ...          ...              ...
# 13592894          0.0           0         None              NaN
# 13592895          0.0           0         None              NaN
# 13592896          0.0           0         None              NaN
# 13592897          0.0           0         None              NaN
# 13592898          0.0           0         None              NaN
#
#          player3_team_city player3_team_nickname player3_team_abbreviation  \
# 0                     None                  None                      None
# 1                  Phoenix                  Suns                       PHX
# 2                     None                  None                      None
# 3                     None                  None                      None
# 4                     None                  None                      None
# ...                    ...                   ...                       ...
# 13592894              None                  None                      None
# 13592895              None                  None                      None
# 13592896              None                  None                      None
# 13592897              None                  None                      None
# 13592898              None                  None                      None
#
#           video_available_flag
# 0                            0
# 1                            0
# 2                            0
# 3                            0
# 4                            0
# ...                        ...
# 13592894                     1
# 13592895                     1
# 13592896                     1
# 13592897                     1
# 13592898                     1
#
# [13592899 rows x 34 columns]

# %%
pd.set_option("display.max_rows", None)
df1 = df.loc[df['game_id'] == 29600012]
df1.head()
# Out:
#     game_id  eventnum  eventmsgtype  eventmsgactiontype  period wctimestring  \
# 0  29600012         0            12                   0       1     14:43 PM
# 1  29600012         2            10                   0       1     14:50 PM
# 2  29600012         3             2                   1       1     14:51 PM
# 3  29600012         4             4                   0       1     14:51 PM
# 4  29600012         5             2                   1       1     14:51 PM
#
#   pctimestring                              homedescription  \
# 0        12:00                                         None
# 1        12:00  Jump Ball O'Neal vs. Kleine: Tip to Cassell
# 2        11:45                                         None
# 3        11:43                 O'Neal REBOUND (Off:0 Def:1)
# 4        11:29              MISS Ceballos 26' 3PT Jump Shot
#
#                    neutraldescription          visitordescription score  \
# 0  Start of 1st Period (14:43 PM EST)                        None  None
# 1                                None                        None  None
# 2                                None  MISS Cassell 15' Jump Shot  None
# 3                                None                        None  None
# 4                                None                        None  None
#
#   scoremargin  person1type  player1_id      player1_name  player1_team_id  \
# 0        None          0.0           0              None              NaN
# 1        None          4.0         406  Shaquille O'Neal     1.610613e+09
# 2        None          5.0         208       Sam Cassell     1.610613e+09
# 3        None          4.0         406  Shaquille O'Neal     1.610613e+09
# 4        None          4.0          76   Cedric Ceballos     1.610613e+09
#
#   player1_team_city player1_team_nickname player1_team_abbreviation  \
# 0              None                  None                      None
# 1       Los Angeles                Lakers                       LAL
# 2           Phoenix                  Suns                       PHX
# 3       Los Angeles                Lakers                       LAL
# 4       Los Angeles                Lakers                       LAL
#
#    person2type  player2_id player2_name  player2_team_id player2_team_city  \
# 0          0.0           0         None              NaN              None
# 1          5.0         170   Joe Kleine     1.610613e+09           Phoenix
# 2          0.0           0         None              NaN              None
# 3          0.0           0         None              NaN              None
# 4          0.0           0         None              NaN              None
#
#   player2_team_nickname player2_team_abbreviation  person3type  player3_id  \
# 0                  None                      None          0.0           0
# 1                  Suns                       PHX          5.0         208
# 2                  None                      None          0.0           0
# 3                  None                      None          0.0           0
# 4                  None                      None          0.0           0
#
#   player3_name  player3_team_id player3_team_city player3_team_nickname  \
# 0         None              NaN              None                  None
# 1  Sam Cassell     1.610613e+09           Phoenix                  Suns
# 2         None              NaN              None                  None
# 3         None              NaN              None                  None
# 4         None              NaN              None                  None
#
#   player3_team_abbreviation  video_available_flag
# 0                      None                     0
# 1                       PHX                     0
# 2                      None                     0
# 3                      None                     0
# 4                      None                     0

# %%
# Convert homedescription to lowercase
df['homedescription'] = df['homedescription'].str.lower()

# Filter the DataFrame where homedescription is "lakers rebound"
filtered_df = df[df["homedescription"] == "lakers rebound"]

# Get the value counts for eventmsgtype in the filtered DataFrame
eventmsgtype_counts = filtered_df["eventmsgtype"].value_counts()
eventmsgtype_counts
# Out:
# eventmsgtype
# 4    9778
# Name: count, dtype: int64

# %%
df = df.drop(columns=["player2_team_city", "wctimestring", "neutraldescription", "player3_team_city", 
                      "player3_team_abbreviation", "player1_team_city", "player1_team_abbreviation", 
                      "player2_team_abbreviation", "video_available_flag"])

# %%
df["player2_team_nickname"].unique()
# Out:
# array([None, 'Suns', 'Lakers', 'Hawks', 'Heat', 'Cavaliers', 'Nets',
#        'Clippers', 'Warriors', 'Kings', 'Rockets', 'Bulls', 'Celtics',
#        'Knicks', 'Raptors', 'Mavericks', 'Nuggets', 'Bucks', '76ers',
#        'Spurs', 'Timberwolves', 'SuperSonics', 'Jazz', 'Bullets', 'Magic',
#        'Pacers', 'Pistons', 'Hornets', 'Trail Blazers', 'Grizzlies',
#        'Wizards', 'West', 'East', 'Bobcats', 'Thunder', 'Pelicans',
#        'Fenerbahce Ulker', 'Basket', 'CSKA', 'Maccabi Haifa',
#        'Maccabi Electra', 'Alba Berlin', 'Flamengo',
#        'Fenerbahce Sports Club', 'Olimpia Milano', 'Paschoalotto/Bauru',
#        'Real Madrid', 'Shanghai Sharks', 'FC Barcelona Lassa',
#        'San Lorenzo', 'Long-Lions', 'Sharks', 'United', 'LeBron',
#        'Stephen', 'Giannis', 'Durant', "Maccabi Ra'anana", '36ers'],
#       dtype=object)

# %%
# So after seeing that there are many different team names (some of them are not nba teams or they are not updated). 
# I will change the not to date ones, and drop the games where the non nba teams appear, which are:
non_nba_teams = [
    'East', 'West', 'Fenerbahce Ulker', 'Basket', 'CSKA', 'Maccabi Haifa', 
    'Maccabi Electra', 'Alba Berlin', 'Flamengo', 'Fenerbahce Sports Club', 'Olimpia Milano', 
    'Paschoalotto/Bauru', 'Real Madrid', 'Shanghai Sharks', 'FC Barcelona Lassa', 'San Lorenzo', 
    'Long-Lions', 'Sharks', 'United', 'Stephen', 'LeBron', 'Giannis', 'Durant', 
    "Maccabi Ra'anana", '36ers'
]

# The result will be all the games that I will drop involving non NBA teams or all-star games.
cleaning = df[df['player1_team_nickname'].isin(non_nba_teams)] 
unique_game_ids = cleaning['game_id'].unique()
unique_game_ids
# Out:
# array([39700001, 30300001, 30400001, 30500001, 30600001, 30700001,
#        30900001, 31000001, 31100001, 31200001, 11300001, 11300005,
#        11300008, 11300009, 11300020, 11300027, 11300046, 31300001,
#        11400003, 11400011, 11400022, 11400020, 11400034, 11400055,
#        11400054, 11400067, 11400070, 11400075, 11400104, 31400001,
#        11500008, 11500016, 11500021, 11500024, 11500030, 11500034,
#        11500043, 11500041, 11500069, 31500001, 11600003, 11600010,
#        11600020, 11600060, 31600001, 11700005, 11700021, 11700026,
#        11700039, 11700055, 31700001, 31800001, 31900001, 32000001,
#        32100001, 12200002, 12200008, 12200027, 12200025, 12200038,
#        32200001])

# %%
game_ids_to_drop = [39700001, 30300001, 30400001, 30500001, 30600001, 30700001,
       30900001, 31000001, 31100001, 31200001, 11300001, 11300005,
       11300008, 11300009, 11300020, 11300027, 11300046, 31300001,
       11400003, 11400011, 11400022, 11400020, 11400034, 11400055,
       11400054, 11400067, 11400070, 11400075, 11400104, 31400001,
       11500008, 11500016, 11500021, 11500024, 11500030, 11500034,
       11500043, 11500041, 11500069, 31500001, 11600003, 11600010,
       11600020, 11600060, 31600001, 11700005, 11700021, 11700026,
       11700039, 11700055, 31700001, 31800001, 31900001, 32000001,
       32100001, 12200002, 12200008, 12200027, 12200025, 12200038,
       32200001]

df = df[~df["game_id"].isin(game_ids_to_drop)]

# %%
old_nba_teams = ['SuperSonics', 'Bullets', 'Bobcats']
new_nba_teams = ["Thunder", "Wizards", "Hornets"]

team_name_mapping = dict(zip(old_nba_teams, new_nba_teams))

# Replace the old team names with new team names in both columns
df["player1_team_nickname"] = df["player1_team_nickname"].replace(team_name_mapping)
df["player2_team_nickname"] = df["player2_team_nickname"].replace(team_name_mapping)

df["player1_team_nickname"].unique()
# Okay so dropped all the games where there is a team that is not an NBA teamd AND changed the names of the old teams that are nowadays the equivalent.
# Out:
# array([None, 'Lakers', 'Suns', 'Heat', 'Hawks', 'Nets', 'Cavaliers',
#        'Warriors', 'Clippers', 'Rockets', 'Kings', 'Celtics', 'Bulls',
#        'Raptors', 'Knicks', 'Nuggets', 'Mavericks', '76ers', 'Bucks',
#        'Timberwolves', 'Spurs', 'Jazz', 'Thunder', 'Magic', 'Wizards',
#        'Pacers', 'Pistons', 'Hornets', 'Trail Blazers', 'Grizzlies',
#        'Pelicans'], dtype=object)

# %%
# I will not use the team ID, the name will do
df = df.drop(columns=["player1_team_id", "player2_team_id", "player3_team_id"])
